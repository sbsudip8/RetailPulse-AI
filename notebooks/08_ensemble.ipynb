# %%
# Simple weighted average of Prophet + LSTM predictions
import pandas as pd, numpy as np
from sklearn.metrics import mean_absolute_percentage_error

prophet_fc = pd.read_csv('../data/prophet_forecast.csv', parse_dates=['ds'])
# Load your LSTM test predictions saved from Day 6 as a numpy array or CSV

# Ensemble: 60% Prophet + 40% LSTM (tune weights based on individual MAPEs)
# ensemble_pred = 0.6 * prophet_pred + 0.4 * lstm_pred
# mape_ensemble = mean_absolute_percentage_error(actuals, ensemble_pred)
# print(f'Ensemble MAPE: {mape_ensemble*100:.2f}%')
