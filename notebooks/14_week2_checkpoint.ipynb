# %%
import mlflow

mlflow.set_experiment('RetailPulse-Week2')

with mlflow.start_run(run_name='week2_summary'):
    mlflow.log_metric('churn_auc_roc',      0.91)   # your actual value
    mlflow.log_metric('ensemble_mape',      0.08)   # your actual value
    mlflow.log_artifact('../data/drift_report.html')
    mlflow.log_artifact('../data/churn_scores.csv')
    mlflow.log_artifact('../data/inventory_recommendations.csv')

print("Week 2 checkpoint logged ✓")
# Out:
# 2026/06/10 11:33:40 INFO mlflow.tracking.fluent: Experiment with name 'RetailPulse-Week2' does not exist. Creating a new experiment.
# Week 2 checkpoint logged ✓
