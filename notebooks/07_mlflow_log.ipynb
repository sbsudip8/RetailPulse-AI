# %%
import mlflow

mlflow.set_experiment('RetailPulse-Week1')

with mlflow.start_run(run_name='prophet_baseline'):
    mlflow.log_metric('mape_prophet', 0.089)   # replace with your actual value
    mlflow.log_artifact('../data/prophet_forecast.csv')

with mlflow.start_run(run_name='lstm_baseline'):
    mlflow.log_metric('mape_lstm', 0.11)        # replace with your actual value
    mlflow.log_artifact('../models/lstm_model.pth')

print("Logged to MLflow ✓")
# Out:
# Logged to MLflow ✓
